# %% [markdown]
# <a href="https://colab.research.google.com/github/durgeshgitup/MA22C013_2023_PL/blob/main/Assignment/Assignment_5/Row_swap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def swaprow(i, j, A):
  tmp = A[i, :]
  A[i, :] = A[j, :]
  A[j, :] = tmp
  return A

# %%
def swaprow_1(i, j, A):
  A[[i,j]] = A[[j,i]]
  return A

# %%
A = np.array([[5,7,6],[2,6,7],[8,9,1]])
print(A)
# Out:
# [[5 7 6]
#  [2 6 7]
#  [8 9 1]]

# %%
swaprow_1(0,1,A)
# Out:
# array([[2, 6, 7],
#        [5, 7, 6],
#        [8, 9, 1]])
